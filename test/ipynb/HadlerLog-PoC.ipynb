# %%
from h2o.estimators.gbm import H2OGradientBoostingEstimator
from h2o.estimators.glm import H2OGeneralizedLinearEstimator
from h2o.estimators.deeplearning import H2ODeepLearningEstimator
from h2o.estimators.random_forest import H2ORandomForestEstimator
from h2o.model.metrics_base import H2OBinomialModelMetrics as H2OBinomialModelMetrics
from h2o.model.metrics_base import H2OMultinomialModelMetrics as H2OMultinomialModelMetrics
from h2o.model.metrics_base import H2ORegressionModelMetrics as H2ORegressionModelMetrics

from h2o import save_model as save_model
from h2o import load_model as load_model
from h2o import init as init
from h2o import connect as connect
from h2o import connection as connection
from h2o import cluster as cluster


from h2o import H2OFrame as H2OFrame
from pandas import DataFrame as DataFrame
import json
import time
from collections import OrderedDict as OrderedDict
from hashlib import md5 as md5
from hashlib import sha256 as sha256
from os import makedirs as mkdir
from os import path as path
from shutil import copyfile
import copy

__name__ = 'H2OHandler'

class H2OHandler(object):
    """
    H2OHandler

    Train: Get some analysis list of tuplas (analysis_results.json +  (algorithm + normalzations over a Dataframe) and launch de analysis on H2O platform
    predict: Get some list of [analysis_results.json] and load and execute algorithm
    Algorithms and model operation:

    "H2OGradientBoostingEstimator" :{
      "id" : "number",
      "module" : "h2o.estimators.gbm",
      "types": {
        "binomial": {"active" : true, "valued": "enum"},
        "multinomial": {"active" : true, "valued": "enum"},
        "regression" : {"active" : true, "valued": "float64"},
        "topology" : {"active" : false, "valued": "float64"}
      }

    "H2OGeneralizedLinearEstimator" :{
      "id" : "number",
      "module" : "h2o.estimators.glm",
      "types": {
        "binomial": {"active" : true, "valued": "enum"},
        "multinomial": {"active" : true, "valued": "enum"},
        "regression" : {"active" : true, "valued": "float64"},
        "topology" : {"active" : false, "valued": "float64"}
      }

    "H2ODeepLearningEstimator" :{
      "id" : "number",
      "module" : "h2o.estimators.deeplearning",
      "types": {
        "binomial": {"active" : true, "valued": "enum"},
        "multinomial": {"active" : true, "valued": "enum"},
        "regression" : {"active" : true, "valued": "float64"},
        "topology" : {"active" : false, "valued": "float64"}
      }

    "H2ORandomForestEstimator" :{
      "id" : "number",
      "module" : "h2o.estimators.random_forest",
      "types": {
        "types": {
          "binomial": {"active" : true, "valued": "enum"},
          "multinomial": {"active" : true, "valued": "enum"},
          "regression" : {"active" : true, "valued": "float64"},
          "topology" : {"active" : false, "valued": "float64"}
        }

    Status Codes:
        -1 : Uninitialized
        0: Success
        1: Error

    """

    def __init__(self):
        self._model_base = None
        self.path_localfs = r'D:/Data/models'
        self.path_hdfs = None
        self.url = 'http://127.0.0.1:54321'
        self.nthreads = 6
        self.ice_root = r'D:/Data/logs'
        self.max_mem_size = '8G'
        self.start_h2o = True
        self._debug = True
        self._framework = 'h2o'

        try:
            self._h2o_session = connect(url=self.url)
        except:
            init(url=self.url, nthreads=self.nthreads, ice_root=self.ice_root, max_mem_size=self.max_mem_size)
            self._h2o_session = connection()

        print('Session_id: ' + self._h2o_session.session_id())

    def __del__(self):
        self._h2o_session.close()

    @classmethod
    def shutdown_cluster(cls):
        try:
            cluster().shutdown()
        except:
            print('H20-cluster not working')

    @staticmethod
    def _hash_keys(hash_type, filename):

            if hash_type == 'MD5':
                return md5(open(filename, 'rb').read()).hexdigest()
            elif hash_type == 'SHA256':
                return sha256(open(filename, 'rb').read()).hexdigest()

    def order_training(self, analysis_id, training_frame, valid_frame, analysis_list):
        assert isinstance(analysis_id, str)
        assert isinstance(training_frame, DataFrame)
        assert isinstance(valid_frame, DataFrame) or valid_frame is None
        assert isinstance(analysis_list, list)


        status = -1  # Operation Code
        model_list = list()
        analysis_timestamp = str(time.time())

        training_frame = H2OFrame(python_obj=training_frame)
        if valid_frame is not None:
            valid_frame = H2OFrame(python_obj=valid_frame)

        for algorithm_description, normalization in analysis_list:

            # Initializing base structures
            struct_ar = json.load(algorithm_description, object_pairs_hook=OrderedDict)
            #print(struct_ar)

            # Generating base_path
            load_path = list()
            load_path.append(self.path_localfs)
            load_path.append('/')
            load_path.append(self._framework)
            load_path.append('/')
            load_path.append(struct_ar['model_id'])
            load_path.append('/')
            load_path.append('train')
            load_path.append('/')
            base_path = ''.join(load_path)
            if not path.exists(base_path):
                mkdir(base_path, 0o0777)

            if normalization is not None:
                struct_ns = json.load(normalization, object_pairs_hook=OrderedDict)
            else:
                struct_ns = None

            assert isinstance(struct_ar, OrderedDict)
            assert isinstance(struct_ns, OrderedDict) or normalization is None

            for each_model in struct_ar['model_parameters']['h2o']:

                final_ar_model = copy.deepcopy(struct_ar)
                final_ar_model['type'] = 'train'
                final_ar_model['timestamp'] = analysis_timestamp
                model_timestamp = str(time.time())

                y = each_model['parameters']['response_column']['value']
                x = training_frame.col_names
                x.remove(y)

                if each_model['types'][0]['active']:
                    if each_model['types'][0]['type'] in ['binomial', 'multinomial']:
                        training_frame[y] = training_frame[y].asfactor()
                        if valid_frame is not None:
                            valid_frame[y] = valid_frame[y].asfactor()

                model_command = list()
                model_command.append(each_model['model'])
                model_command.append("(")
                model_command.append("training_frame=training_frame")

                if valid_frame is not None:
                    model_command.append(", validation_frame=valid_frame")

                model_id = each_model['model'] + '_' + model_timestamp
                model_command.append(", model_id='%s'" % model_id)

                for key, value in each_model['parameters'].items():
                    if value['seleccionable']:
                        if isinstance(value['value'], str):
                            model_command.append(", %s=\'%s\'" % (key, value['value']))
                        else:
                            model_command.append(", %s=%s" % (key, value['value']))

                model_command.append(")")
                model_command = ''.join(model_command)
                print(model_command)

                #Modify when hdfs method will be implemented actually first value must be localfs

                # Generating model
                if self._debug:
                            connection().start_logging(
                                base_path + final_ar_model['log_path'][0]['value']+'\DEBUG'+model_id+'.log')
                self._model_base = eval(model_command)
                if valid_frame is not None:
                    self._model_base.train(x=x, y=y, training_frame=training_frame, validation_frame=valid_frame)
                else:
                    self._model_base.train(x=x, y=y, training_frame=training_frame)
                if self._debug:
                    connection().stop_logging()

                model_path = base_path + final_ar_model['load_path'][0]['value']
                if not path.exists(model_path):
                    mkdir(model_path, 0o0777)
                save_model(model=self._model_base, path=model_path, force=True)


                # Generating json ar.json
                # setting load_path
                counter_loop = True  #define First element
                for each_storage_type in final_ar_model['load_path']:
                    if counter_loop:
                        if each_storage_type['type'] == 'localfs':
                            if not path.exists(model_path):
                                mkdir(model_path, 0o0777)

                            each_storage_type['value'] = model_path + '/' + model_id
                            # Generating hash tags
                            for each_hash_type in each_storage_type['hash_list']:
                                if each_hash_type['type'] == 'MD5':
                                    each_hash_type['value'] = self._hash_keys(each_hash_type['type'],
                                                                              each_storage_type['value'])
                                elif each_hash_type['type'] == 'SHA256':
                                    each_hash_type['value'] = self._hash_keys(each_hash_type['type'],
                                                                              each_storage_type['value'])
                        elif each_storage_type['type'] == 'hdfs':
                            None
                        counter_loop = False
                    else:
                        if each_storage_type['type'] == 'localfs':
                            if not path.exists(base_path + each_storage_type['value']):
                                mkdir(base_path + each_storage_type['value'], 0o0777)
                            each_storage_type['value'] = base_path + each_storage_type['value'] + '/' + model_id
                            self._replicate_file(each_storage_type['type'],
                                                 each_storage_type['value'],
                                                 final_ar_model['load_path'][0]['type'],
                                                 final_ar_model['load_path'][0]['value'])
                            # Generating hash tags
                            for each_hash_type in each_storage_type['hash_list']:
                                if each_hash_type['type'] == 'MD5':
                                    each_hash_type['value'] = self._hash_keys(each_hash_type['type'],
                                                                              each_storage_type['value'])
                                elif each_hash_type['type'] == 'SHA256':
                                    each_hash_type['value'] = self._hash_keys(each_hash_type['type'],
                                                                              each_storage_type['value'])
                        elif each_storage_type['type'] == 'hdfs':
                            None

                # Generating model parameters
                final_ar_model['model_parameters']['h2o'] = list()
                final_ar_model['model_parameters']['h2o'].append(each_model.copy())
                final_ar_model['model_parameters']['h2o'][0]['parameters']['model_id'] = model_id

                # Generating metrics
                final_ar_model['metrics'] = OrderedDict()
                final_ar_model['metrics']['train'] = self._generate_metrics(dataframe=None, source='train')
                if valid_frame is not None:
                    final_ar_model['metrics']['valid'] = self._generate_metrics(dataframe=None, source='valid')
                final_ar_model['metrics']['xval'] = self._generate_metrics(dataframe=None, source='xval')

                # Generating log_path
                for each_storage_type in final_ar_model['log_path']:
                    if each_storage_type['type'] == 'localfs':
                        if not path.exists(base_path + each_storage_type['value']):
                            mkdir(base_path + each_storage_type['value'], 0o0777)
                        each_storage_type['value'] = base_path + each_storage_type['value'] + '/' + model_id + '.log'
                    elif each_storage_type['type'] == 'hdfs':
                        None

                # writing ar.json file
                json_files = list()
                for each_storage_type in final_ar_model['json_path']:
                    if each_storage_type['type'] == 'localfs':
                        if not path.exists(base_path + each_storage_type['value']):
                            mkdir(base_path + each_storage_type['value'], 0o0777)
                        each_storage_type['value'] = base_path + each_storage_type['value'] + '/' + model_id + '.json'
                        json_files.append(each_storage_type)
                    elif each_storage_type['type'] == 'hdfs':
                        None
                    elif each_storage_type['type'] == 'mongoDB':
                        None
                self._store_files(json_files, final_ar_model)

                model_list.append(final_ar_model)

            return analysis_id, model_list

    def predict(self, dataframe, algorithm_description):
        model_timestamp = str(time.time())

        struct_ar = json.load(algorithm_description, object_pairs_hook=OrderedDict)
        load_fails = True
        hash_fails = True
        counter_storage = 0
        counter_hash = 0

        assert isinstance(struct_ar['load_path'], list)
        while counter_storage < len(struct_ar['load_path']) and load_fails:
            while counter_hash < len(struct_ar['load_path'][counter_storage]['hash_list']) and \
                    hash_fails:
                print('generated_key %s' % self._hash_keys(struct_ar['load_path'][counter_storage]['hash_list']
                                                           [counter_hash]['type'],
                                                           struct_ar['load_path'][counter_storage]['value']))
                print('storage_key %s' % struct_ar['load_path'][counter_storage]['hash_list'][counter_hash]['value'])
                if self._hash_keys(struct_ar['load_path'][counter_storage]['hash_list'][counter_hash]['type'],
                                   struct_ar['load_path'][counter_storage]['value']) == \
                        struct_ar['load_path'][counter_storage]['hash_list'][counter_hash]['value']:
                    load_fails = False
                    hash_fails = False
                    try:
                        self._model_base = load_model(struct_ar['load_path'][counter_storage]['value'])
                    except:
                        print('Model json: invalid')
                else:
                    counter_hash += 1
            counter_hash = 0
            counter_storage += 1

        if load_fails:
            return ('Necesario cargar un modelo valid o ar.json valido')


        predict_frame = H2OFrame(python_obj=dataframe)

        y = struct_ar['model_parameters']['h2o'][0]['parameters']['response_column']['value']
        if struct_ar['model_parameters']['h2o'][0]['types'][0]['type'] in ['binomial', 'multinomial']:
            predict_frame[y].asfactor()

        struct_ar['type'] = 'predict'
        struct_ar['timestamp'] = model_timestamp
        struct_ar['metrics'] = OrderedDict()
        struct_ar['metrics']['predict'] = self._generate_metrics(predict_frame, source=None)

        # writing ar.json file
        json_files = list()
        for each_storage_type in struct_ar['json_path']:
            if each_storage_type['type'] == 'localfs':
                if not path.exists(path.dirname(each_storage_type['value'].replace('train', 'predict'))):
                    mkdir(path.dirname(each_storage_type['value'].replace('train', 'predict')), 0o0777)
                each_storage_type['value'] = each_storage_type['value'].replace('train', 'predict')\
                    .replace('.json', '_' + model_timestamp + '.json')
                json_files.append(each_storage_type)
            elif each_storage_type['type'] == 'hdfs':
                None
            elif each_storage_type['type'] == 'mongoDB':
                None
        self._store_files(json_files, struct_ar)

        return (self._model_base.predict(predict_frame).as_data_frame(use_pandas=True), struct_ar)

    def _generate_metrics(self, dataframe, source):
        """
        Generate model metrics for this model on test_data.

        :param H2OFrame test_data: Data set for which model metrics shall be computed against. All three of train,
            valid and xval arguments are ignored if test_data is not None.
        :param source 'train': Report the training metrics for the model.
        :param source 'valid': Report the validation metrics for the model.
        :param source 'xval': Report the cross-validation metrics for the model. If train and valid are True, then it
            defaults to True.
        """

        model_metrics = OrderedDict()

        if dataframe is not None:
            perf_metrics = self._model_base.model_performance(dataframe)
        else:
            if source == 'valid':
                perf_metrics = self._model_base.model_performance(valid=True)
            elif source == 'xval':
                perf_metrics = self._model_base.model_performance(xval=True)
            else:
                perf_metrics = self._model_base.model_performance(train=True)

        for parameter, value in perf_metrics._metric_json.items():
            if parameter in ['hit_ratio_table', 'gains_lift_table', 'max_criteria_and_metric_scores']:
                model_metrics[parameter] = value.as_data_frame().to_json(orient='split')
            elif parameter in ['cm']:
                model_metrics[parameter] = value['table'].as_data_frame().to_json(orient='split')
            elif parameter in ['thresholds_and_metric_scores']:
                model_metrics['cm'] = OrderedDict()
                for each_parameter in ['min_per_class_accuracy', 'absolute_mcc', 'precision', 'accuracy',
                                       'f0point5', 'f2', 'f1', 'mean_per_class_accuracy']:
                    model_metrics['cm'][each_parameter] = \
                        perf_metrics.confusion_matrix(
                            metrics=each_parameter).table.as_data_frame().to_json(orient='split')
                model_metrics[parameter] = value.as_data_frame().to_json(orient='split')
            elif not isinstance(value, dict) and parameter not in ['model_checksum', 'frame_checksum', 'description']:
                model_metrics[parameter] = value

        return model_metrics.copy()

    def get_metric(self, algorithm_description, metric, source):  # not tested
        try:
            struct_ar = OrderedDict(json.load(algorithm_description))
            model_metrics = struct_ar['metrics']['source']
        except:
            return ('Necesario cargar un modelo valid o ar.json valido')
        try:
            return struct_ar['metrics']['source'][metric]
        except:
            return 'Not Found'

    @staticmethod
    def _replicate_file(type_dest, path_dest, type_source, path_source):
        if type_source == 'localfs':
            if type_dest == 'localfs':
                if not path.exists(path.dirname(path_dest)):
                    mkdir(path.dirname(path_dest), 0o0777)
                copyfile(path_source, path_dest)
            elif type_dest == 'hdfs':
                None
            elif type_dest == 'mongoDB':
                None
        elif type_source == 'hdfs':
            if type_dest == 'localfs':
                None
            elif type_dest == 'hdfs':
                None
            elif type_dest == 'mongoDB':
                None
        elif type_source == 'mongoDB':
            if type_dest == 'localfs':
                None
            elif type_dest == 'hdfs':
                None
            elif type_dest == 'mongoDB':
                None

    @staticmethod
    def _store_files(json_files, struct_ar):
        for each_storage_type in json_files:
            if each_storage_type['type'] == 'localfs':
                file = open(each_storage_type['value'], 'w')
                json.dump(struct_ar, file, indent=4)
                file.close()
            elif each_storage_type['type'] == 'hdfs':
                None
            elif each_storage_type['type'] == 'mongoDB':
                None

    @staticmethod
    def _store_files(json_files, struct_ar):
        for each_storage_type in json_files:
            if each_storage_type['type'] == 'localfs':
                file = open(each_storage_type['value'], 'w')
                json.dump(struct_ar, file, indent=4)
                file.close()
            elif each_storage_type['type'] == 'hdfs':
                None
            elif each_storage_type['type'] == 'mongoDB':
                None

# %%
init(ice_root='D:/Data/logs', nthreads=2, max_mem_size='8G')
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321..... not found.
# Attempting to start a local H2O server...
# ; OpenJDK 64-Bit Server VM (Zulu 8.17.0.3-win64) (build 25.102-b14, mixed mode)
#   Starting server from D:\Anaconda3\lib\site-packages\h2o\backend\bin\h2o.jar
#   Ice root: D:/Data/logs
#   JVM stdout: C:\Users\Public\Documents\Wondershare\CreatorTemp\tmp6nirnv5x\h2o_e2its_started_from_python.out
#   JVM stderr: C:\Users\Public\Documents\Wondershare\CreatorTemp\tmp6nirnv5x\h2o_e2its_started_from_python.err
#   Server is running at http://127.0.0.1:54321
# Connecting to H2O server at http://127.0.0.1:54321... successful.
# --------------------------  ------------------------------
# H2O cluster uptime:         03 secs
# H2O cluster version:        3.10.4.6
# H2O cluster version age:    1 month
# H2O cluster name:           H2O_from_python_e2its_e2t404
# H2O cluster total nodes:    1
# H2O cluster free memory:    7.111 Gb
# H2O cluster total cores:    8
# H2O cluster allowed cores:  2
# H2O cluster status:         accepting new members, healthy
# H2O connection url:         http://127.0.0.1:54321
# H2O connection proxy:
# H2O internal security:      False
# Python version:             3.5.2 final
# --------------------------  ------------------------------

# %%
connection = connection()

# %%
print('h2o_'+ connection.ip() + '-' + connection.port() + '-3-info.log')
# Out:
# h2o_127.0.0.1-54321-3-info.log

# %%
type(connection)
# Out:
# h2o.backend.connection.H2OConnection

# %%
import h2o
h2o.log_and_echo('Session: %s process %s started at: %s' % (connection.session_id(), 'model_id_name', time.time()))

# %%
from h2o.backend import H2OCluster, H2OLocalServer
from h2o.exceptions import H2OConnectionError, H2OServerError, H2OResponseError, H2OValueError

# %%
from pandas import DataFrame as DataFrame
from pandas import concat as concat
import numpy as np
import os
from six.moves import cPickle as pickle

def reformat(dataset, labels):
        dataset = DataFrame(dataset.reshape((-1, image_size * image_size)).astype(np.float32))
        # Map 0 to [1.0, 0.0, 0.0 ...], 1 to [0.0, 1.0, 0.0 ...]
        columns = list()
        for each_value in dataset.columns.values:
            columns.append(str(each_value))
        dataset.columns = columns
        labels = DataFrame(labels.reshape((-1, 1)).astype(str))
        columns = list()
        for each_value in labels.columns.values:
            columns.append('objective' + str(each_value))
        labels.columns = columns
        # labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
        return dataset, labels

def convertir_binomial(x):
        if int(x) % 2 == 0:
            return 1
        else:
            return 0

os.chdir('d:/Data/Gdeeplearning-Udacity')
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
        save = pickle.load(f)
        train_dataset = save['train_dataset']
        train_labels = save['train_labels']
        valid_dataset = save['valid_dataset']
        valid_labels = save['valid_labels']
        test_dataset = save['test_dataset']
        test_labels = save['test_labels']
        del save  # hint to help gc free up memory

train_dataset = train_dataset[-20001:-1]
train_labels = train_labels[-20001:-1]

print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Validation set', test_dataset.shape, test_labels.shape)

    # In[5]:

image_size = 28
num_labels = 10

pd_train_dataset, pd_train_labels = reformat(train_dataset, train_labels)
pd_valid_dataset, pd_valid_labels = reformat(valid_dataset, valid_labels)
pd_test_dataset, pd_test_labels = reformat(valid_dataset, valid_labels)
pd_train_dataset = concat([pd_train_dataset, pd_train_labels], axis=1)
pd_valid_dataset = concat([pd_valid_dataset, pd_valid_labels], axis=1)
pd_test_dataset = concat([pd_test_dataset, pd_test_labels], axis=1)

print('Training set', pd_train_dataset.shape)
print('Validation set', pd_valid_dataset.shape)
print('Test set', pd_test_dataset.shape)

    # Binomial_test

pd_train_dataset['objective0'] = pd_train_dataset['objective0'].apply(convertir_binomial)
pd_valid_dataset['objective0'] = pd_valid_dataset['objective0'].apply(convertir_binomial)
pd_test_dataset['objective0'] = pd_test_dataset['objective0'].apply(convertir_binomial)
# Out:
# Training set (20000, 28, 28) (20000,)
# Validation set (10000, 28, 28) (10000,)
# Validation set (10000, 28, 28) (10000,)
# Training set (20000, 785)
# Validation set (10000, 785)
# Test set (10000, 785)
# Connecting to H2O server at http://127.0.0.1:54321... successful.
# --------------------------  ----------------------------
# H2O cluster uptime:         51 mins 53 secs
# H2O cluster version:        3.10.4.6
# H2O cluster version age:    1 month
# H2O cluster name:           H2O_from_python_e2its_e2t404
# H2O cluster total nodes:    1
# H2O cluster free memory:    6.346 Gb
# H2O cluster total cores:    8
# H2O cluster allowed cores:  2
# H2O cluster status:         locked, healthy
# H2O connection url:         http://127.0.0.1:54321
# H2O connection proxy:
# H2O internal security:      False
# Python version:             3.5.2 final
# --------------------------  ----------------------------
# Session_id: _sid_a22e
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# H2OGradientBoostingEstimator(training_frame=training_frame, validation_frame=valid_frame, model_id='H2OGradientBoostingEstimator_1496396879.7755053', nfolds=2, keep_cross_validation_predictions=True, keep_cross_validation_fold_assignment=True, score_each_iteration=True, score_tree_interval=1000, fold_assignment='auto', response_column='objective0', ignore_const_cols=True, balance_classes=True, max_after_balance_size=5.0, max_hit_ratio_k=3, ntrees=5, max_depth=10, max_runtime_secs=100, learn_rate=0.05, learn_rate_annealing=1.0, distribution='bernoulli')
# Now logging all API requests to file 'D:/Data/models/h2o/PoC-binomial/train/log\\DEBUGH2OGradientBoostingEstimator_1496396879.7755053.log'
# gbm Model Build progress: |███████████████████████████████████████████████| 100%
# Logging stopped.
# H2OGeneralizedLinearEstimator(training_frame=training_frame, validation_frame=valid_frame, model_id='H2OGeneralizedLinearEstimator_1496396927.20715', nfolds=2, seed=-1, keep_cross_validation_predictions=True, keep_cross_validation_fold_assignment=True, fold_assignment='auto', response_column='objective0', score_each_iteration=True, family='binomial', solver='auto', alpha=1, standardize=False, balance_classes=True, max_hit_ratio_k=3, max_runtime_secs=100)
# Now logging all API requests to file 'D:/Data/models/h2o/PoC-binomial/train/log\\DEBUGH2OGeneralizedLinearEstimator_1496396927.20715.log'
# glm Model Build progress: |███████████████████████████████████████████████| 100%
# Logging stopped.
# H2ODeepLearningEstimator(training_frame=training_frame, validation_frame=valid_frame, model_id='H2ODeepLearningEstimator_1496397003.5302677', nfolds=2, keep_cross_validation_predictions=True, keep_cross_validation_fold_assignment=True, response_column='objective0', score_each_iteration=True, max_confusion_matrix_size=20, max_hit_ratio_k=3, standardize=False, activation='rectifier', hidden=[200, 200], epochs=10.0, train_samples_per_iteration=128, target_ratio_comm_to_comp=0.5, adaptive_rate=True, l2=0.005, distribution='bernoulli', max_runtime_secs=100.0)
# Now logging all API requests to file 'D:/Data/models/h2o/PoC-binomial/train/log\\DEBUGH2ODeepLearningEstimator_1496397003.5302677.log'
# deeplearning Model Build progress: |██████████████████████████████████████| 100%
# Logging stopped.
# H2ORandomForestEstimator(training_frame=training_frame, validation_frame=valid_frame, model_id='H2ORandomForestEstimator_1496397096.371754', nfolds=2, keep_cross_validation_predictions=True, keep_cross_validation_fold_assignment=True, score_each_iteration=True, fold_assignment='auto', response_column='objective0', balance_classes=True, max_hit_ratio_k=3, ntrees=5, max_depth=10, max_runtime_secs=100)
# Now logging all API requests to file 'D:/Data/models/h2o/PoC-binomial/train/log\\DEBUGH2ORandomForestEstimator_1496397096.371754.log'
# drf Model Build progress: |███████████████████████████████████████████████| 100%
# Logging stopped.
# H2O session _sid_a22e closed.

# %%
model =H2ODeepLearningEstimator(model_id='H2ODeepLearningEstimator_1496401427.7939088.2', nfolds=2, keep_cross_validation_predictions=True, keep_cross_validation_fold_assignment=True, response_column='objective0', score_each_iteration=True, max_confusion_matrix_size=20, max_hit_ratio_k=3, standardize=False, activation='rectifier', hidden=[200, 200], epochs=10.0, train_samples_per_iteration=128, target_ratio_comm_to_comp=0.5, adaptive_rate=True, l2=0.005, distribution='bernoulli', max_runtime_secs=100.0, rate=0.05, rate_annealing=0.0001)

# %%
training_frame=H2OFrame(python_obj=pd_train_dataset)
y = 'objective0'
x = training_frame.col_names
training_frame[y] = training_frame[y].asfactor()

model.train(training_frame=training_frame, x=x, y=y)
# Out:
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# deeplearning Model Build progress: |██████████████████████████████████████| 100%

# %%
params = model.get_params()

# %%
import pprint
pprint.pprint(params)
# Out:
# {'activation': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                            'schema_type': 'Iced',
#                            'schema_version': 3},
#                 'actual_value': 'Rectifier',
#                 'default_value': 'Rectifier',
#                 'gridable': True,
#                 'help': 'Activation function.',
#                 'is_member_of_frames': [],
#                 'is_mutually_exclusive_with': [],
#                 'label': 'activation',
#                 'level': 'critical',
#                 'name': 'activation',
#                 'required': False,
#                 'type': 'enum',
#                 'values': ['Tanh',
#                            'TanhWithDropout',
#                            'Rectifier',
#                            'RectifierWithDropout',
#                            'Maxout',
#                            'MaxoutWithDropout']},
#  'adaptive_rate': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                               'schema_type': 'Iced',
#                               'schema_version': 3},
#                    'actual_value': True,
#                    'default_value': True,
#                    'gridable': True,
#                    'help': 'Adaptive learning rate.',
#                    'is_member_of_frames': [],
#                    'is_mutually_exclusive_with': [],
#                    'label': 'adaptive_rate',
#                    'level': 'secondary',
#                    'name': 'adaptive_rate',
#                    'required': False,
#                    'type': 'boolean',
#                    'values': []},
#  'autoencoder': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                             'schema_type': 'Iced',
#                             'schema_version': 3},
#                  'actual_value': False,
#                  'default_value': False,
#                  'gridable': False,
#                  'help': 'Auto-Encoder.',
#                  'is_member_of_frames': [],
#                  'is_mutually_exclusive_with': [],
#                  'label': 'autoencoder',
#                  'level': 'secondary',
#                  'name': 'autoencoder',
#                  'required': False,
#                  'type': 'boolean',
#                  'values': []},
#  'average_activation': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                                    'schema_type': 'Iced',
#                                    'schema_version': 3},
#                         'actual_value': 0.0,
#                         'default_value': 0.0,
#                         'gridable': True,
#                         'help': 'Average activation for sparse auto-encoder. '
#                                 '#Experimental',
#                         'is_member_of_frames': [],
#                         'is_mutually_exclusive_with': [],
#                         'label': 'average_activation',
#                         'level': 'expert',
#                         'name': 'average_activation',
#                         'required': False,
#                         'type': 'double',
#                         'values': []},
#  'balance_classes': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                                 'schema_type': 'Iced',
#                                 'schema_version': 3},
#                      'actual_value': False,
#                      'default_value': False,
#                      'gridable': True,
#                      'help': 'Balance training data class counts via '
#                              'over/under-sampling (for imbalanced data).',
#                      'is_member_of_frames': [],
#                      'is_mutually_exclusive_with': [],
#                      'label': 'balance_classes',
#                      'level': 'secondary',
#                      'name': 'balance_classes',
#                      'required': False,
#                      'type': 'boolean',
#                      'values': []},
#  'categorical_encoding': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                                      'schema_type': 'Iced',
#                                      'schema_version': 3},
#                           'actual_value': 'AUTO',
#                           'default_value': 'AUTO',
#                           'gridable': True,
#                           'help': 'Encoding scheme for categorical features',
#                           'is_member_of_frames': [],
#                           'is_mutually_exclusive_with': [],
#                           'label': 'categorical_encoding',
#                           'level': 'secondary',
#                           'name': 'categorical_encoding',
#                           'required': False,
#                           'type': 'enum',
#                           'values': ['AUTO',
#                                      'Enum',
#                                      'OneHotInternal',
#                                      'OneHotExplicit',
#                                      'Binary',
#                                      'Eigen']},
#  'checkpoint': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                            'schema_type': 'Iced',
#                            'schema_version': 3},
#                 'actual_value': None,
#                 'default_value': None,
#                 'gridable': False,
#                 'help': 'Model checkpoint to resume training with.',
#                 'is_member_of_frames': [],
#                 'is_mutually_exclusive_with': [],
#                 'label': 'checkpoint',
#                 'level': 'secondary',
#                 'name': 'checkpoint',
#                 'required': False,
#                 'type': 'Key<Model>',
#                 'values': []},
#  'class_sampling_factors': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                                        'schema_type': 'Iced',
#                                        'schema_version': 3},
#                             'actual_value': None,
#                             'default_value': None,
#                             'gridable': True,
#                             'help': 'Desired over/under-sampling ratios per '
#                                     'class (in lexicographic order). If not '
#                                     'specified, sampling factors will be '
#                                     'automatically computed to obtain class '
#                                     'balance during training. Requires '
#                                     'balance_classes.',
#                             'is_member_of_frames': [],
#                             'is_mutually_exclusive_with': [],
#                             'label': 'class_sampling_factors',
#                             'level': 'expert',
#                             'name': 'class_sampling_factors',
#                             'required': False,
#                             'type': 'float[]',
#                             'values': []},
#  'classification_stop': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                                     'schema_type': 'Iced',
#                                     'schema_version': 3},
#                          'actual_value': 0.0,
#                          'default_value': 0.0,
#                          'gridable': True,
#                          'help': 'Stopping criterion for classification error '
#                                  'fraction on training data (-1 to disable).',
#                          'is_member_of_frames': [],
#                          'is_mutually_exclusive_with': [],
#                          'label': 'classification_stop',
#                          'level': 'expert',
#                          'name': 'classification_stop',
#                          'required': False,
#                          'type': 'double',
#                          'values': []},
#  'col_major': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                           'schema_type': 'Iced',
#                           'schema_version': 3},
#                'actual_value': False,
#                'default_value': False,
#                'gridable': True,
#                'help': '#DEPRECATED Use a column major weight matrix for input '
#                        'layer. Can speed up forward propagation, but might '
#                        'slow down backpropagation.',
#                'is_member_of_frames': [],
#                'is_mutually_exclusive_with': [],
#                'label': 'col_major',
#                'level': 'expert',
#                'name': 'col_major',
#                'required': False,
#                'type': 'boolean',
#                'values': []},
#  'diagnostics': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                             'schema_type': 'Iced',
#                             'schema_version': 3},
#                  'actual_value': True,
#                  'default_value': True,
#                  'gridable': False,
#                  'help': 'Enable diagnostics for hidden layers.',
#                  'is_member_of_frames': [],
#                  'is_mutually_exclusive_with': [],
#                  'label': 'diagnostics',
#                  'level': 'expert',
#                  'name': 'diagnostics',
#                  'required': False,
#                  'type': 'boolean',
#                  'values': []},
#  'distribution': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                              'schema_type': 'Iced',
#                              'schema_version': 3},
#                   'actual_value': 'bernoulli',
#                   'default_value': 'AUTO',
#                   'gridable': True,
#                   'help': 'Distribution function',
#                   'is_member_of_frames': [],
#                   'is_mutually_exclusive_with': [],
#                   'label': 'distribution',
#                   'level': 'secondary',
#                   'name': 'distribution',
#                   'required': False,
#                   'type': 'enum',
#                   'values': ['AUTO',
#                              'bernoulli',
#                              'multinomial',
#                              'gaussian',
#                              'poisson',
#                              'gamma',
#                              'tweedie',
#                              'laplace',
#                              'quantile',
#                              'huber']},
#  'elastic_averaging': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                                   'schema_type': 'Iced',
#                                   'schema_version': 3},
#                        'actual_value': False,
#                        'default_value': False,
#                        'gridable': True,
#                        'help': 'Elastic averaging between compute nodes can '
#                                'improve distributed model convergence. '
#                                '#Experimental',
#                        'is_member_of_frames': [],
#                        'is_mutually_exclusive_with': [],
#                        'label': 'elastic_averaging',
#                        'level': 'expert',
#                        'name': 'elastic_averaging',
#                        'required': False,
#                        'type': 'boolean',
#                        'values': []},
#  'elastic_averaging_moving_rate': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                                               'schema_type': 'Iced',
#                                               'schema_version': 3},
#                                    'actual_value': 0.9,
#                                    'default_value': 0.9,
#                                    'gridable': True,
#                                    'help': 'Elastic averaging moving rate '
#                                            '(only if elastic averaging is '
#                                            'enabled).',
#                                    'is_member_of_frames': [],
#                                    'is_mutually_exclusive_with': [],
#                                    'label': 'elastic_averaging_moving_rate',
#                                    'level': 'expert',
#                                    'name': 'elastic_averaging_moving_rate',
#                                    'required': False,
#                                    'type': 'double',
#                                    'values': []},
#  'elastic_averaging_regularization': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                                                  'schema_type': 'Iced',
#                                                  'schema_version': 3},
#                                       'actual_value': 0.001,
#                                       'default_value': 0.001,
#                                       'gridable': True,
#                                       'help': 'Elastic averaging '
#                                               'regularization strength (only '
#                                               'if elastic averaging is '
#                                               'enabled).',
#                                       'is_member_of_frames': [],
#                                       'is_mutually_exclusive_with': [],
#                                       'label': 'elastic_averaging_regularization',
#                                       'level': 'expert',
#                                       'name': 'elastic_averaging_regularization',
#                                       'required': False,
#                                       'type': 'double',
#                                       'values': []},
#  'epochs': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                        'schema_type': 'Iced',
#                        'schema_version': 3},
#             'actual_value': 0.11740050084965119,
#             'default_value': 10.0,
#             'gridable': True,
#             'help': 'How many times the dataset should be iterated (streamed), '
#                     'can be fractional.',
#             'is_member_of_frames': [],
#             'is_mutually_exclusive_with': [],
#             'label': 'epochs',
#             'level': 'critical',
#             'name': 'epochs',
#             'required': False,
#             'type': 'double',
#             'values': []},
#  'epsilon': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                         'schema_type': 'Iced',
#                         'schema_version': 3},
#              'actual_value': 1e-08,
#              'default_value': 1e-08,
#              'gridable': True,
#              'help': 'Adaptive learning rate smoothing factor (to avoid '
#                      'divisions by zero and allow progress).',
#              'is_member_of_frames': [],
#              'is_mutually_exclusive_with': [],
#              'label': 'epsilon',
#              'level': 'expert',
#              'name': 'epsilon',
#              'required': False,
#              'type': 'double',
#              'values': []},
#  'export_weights_and_biases': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                                           'schema_type': 'Iced',
#                                           'schema_version': 3},
#                                'actual_value': False,
#                                'default_value': False,
#                                'gridable': False,
#                                'help': 'Whether to export Neural Network '
#                                        'weights and biases to H2O Frames.',
#                                'is_member_of_frames': [],
#                                'is_mutually_exclusive_with': [],
#                                'label': 'export_weights_and_biases',
#                                'level': 'expert',
#                                'name': 'export_weights_and_biases',
#                                'required': False,
#                                'type': 'boolean',
#                                'values': []},
#  'fast_mode': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                           'schema_type': 'Iced',
#                           'schema_version': 3},
#                'actual_value': True,
#                'default_value': True,
#                'gridable': True,
#                'help': 'Enable fast mode (minor approximation in '
#                        'back-propagation).',
#                'is_member_of_frames': [],
#                'is_mutually_exclusive_with': [],
#                'label': 'fast_mode',
#                'level': 'expert',
#                'name': 'fast_mode',
#                'required': False,
#                'type': 'boolean',
#                'values': []},
#  'fold_assignment': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                                 'schema_type': 'Iced',
#                                 'schema_version': 3},
#                      'actual_value': 'AUTO',
#                      'default_value': 'AUTO',
#                      'gridable': True,
#                      'help': 'Cross-validation fold assignment scheme, if '
#                              "fold_column is not specified. The 'Stratified' "
#                              'option will stratify the folds based on the '
#                              'response variable, for classification problems.',
#                      'is_member_of_frames': [],
#                      'is_mutually_exclusive_with': [],
#                      'label': 'fold_assignment',
#                      'level': 'secondary',
#                      'name': 'fold_assignment',
#                      'required': False,
#                      'type': 'enum',
#                      'values': ['AUTO', 'Random', 'Modulo', 'Stratified']},
#  'fold_column': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                             'schema_type': 'Iced',
#                             'schema_version': 3},
#                  'actual_value': None,
#                  'default_value': None,
#                  'gridable': True,
#                  'help': 'Column with cross-validation fold index assignment '
#                          'per observation.',
#                  'is_member_of_frames': ['training_frame'],
#                  'is_mutually_exclusive_with': ['response_column',
#                                                 'weights_column',
#                                                 'ignored_columns',
#                                                 'offset_column'],
#                  'label': 'fold_column',
#                  'level': 'secondary',
#                  'name': 'fold_column',
#                  'required': False,
#                  'type': 'VecSpecifier',
#                  'values': []},
#  'force_load_balance': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                                    'schema_type': 'Iced',
#                                    'schema_version': 3},
#                         'actual_value': True,
#                         'default_value': True,
#                         'gridable': True,
#                         'help': 'Force extra load balancing to increase '
#                                 'training speed for small datasets (to keep '
#                                 'all cores busy).',
#                         'is_member_of_frames': [],
#                         'is_mutually_exclusive_with': [],
#                         'label': 'force_load_balance',
#                         'level': 'expert',
#                         'name': 'force_load_balance',
#                         'required': False,
#                         'type': 'boolean',
#                         'values': []},
#  'hidden': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                        'schema_type': 'Iced',
#                        'schema_version': 3},
#             'actual_value': [200, 200],
#             'default_value': [200, 200],
#             'gridable': True,
#             'help': 'Hidden layer sizes (e.g. [100, 100]).',
#             'is_member_of_frames': [],
#             'is_mutually_exclusive_with': [],
#             'label': 'hidden',
#             'level': 'critical',
#             'name': 'hidden',
#             'required': False,
#             'type': 'int[]',
#             'values': []},
#  'hidden_dropout_ratios': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                                       'schema_type': 'Iced',
#                                       'schema_version': 3},
#                            'actual_value': None,
#                            'default_value': None,
#                            'gridable': True,
#                            'help': 'Hidden layer dropout ratios (can improve '
#                                    'generalization), specify one value per '
#                                    'hidden layer, defaults to 0.5.',
#                            'is_member_of_frames': [],
#                            'is_mutually_exclusive_with': [],
#                            'label': 'hidden_dropout_ratios',
#                            'level': 'secondary',
#                            'name': 'hidden_dropout_ratios',
#                            'required': False,
#                            'type': 'double[]',
#                            'values': []},
#  'huber_alpha': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                             'schema_type': 'Iced',
#                             'schema_version': 3},
#                  'actual_value': 0.9,
#                  'default_value': 0.9,
#                  'gridable': True,
#                  'help': 'Desired quantile for Huber/M-regression (threshold '
#                          'between quadratic and linear loss, must be between 0 '
#                          'and 1).',
#                  'is_member_of_frames': [],
#                  'is_mutually_exclusive_with': [],
#                  'label': 'huber_alpha',
#                  'level': 'secondary',
#                  'name': 'huber_alpha',
#                  'required': False,
#                  'type': 'double',
#                  'values': []},
#  'ignore_const_cols': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                                   'schema_type': 'Iced',
#                                   'schema_version': 3},
#                        'actual_value': True,
#                        'default_value': True,
#                        'gridable': False,
#                        'help': 'Ignore constant columns.',
#                        'is_member_of_frames': [],
#                        'is_mutually_exclusive_with': [],
#                        'label': 'ignore_const_cols',
#                        'level': 'critical',
#                        'name': 'ignore_const_cols',
#                        'required': False,
#                        'type': 'boolean',
#                        'values': []},
#  'ignored_columns': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                                 'schema_type': 'Iced',
#                                 'schema_version': 3},
#                      'actual_value': None,
#                      'default_value': None,
#                      'gridable': False,
#                      'help': 'Names of columns to ignore for training.',
#                      'is_member_of_frames': ['training_frame',
#                                              'validation_frame'],
#                      'is_mutually_exclusive_with': ['response_column',
#                                                     'weights_column',
#                                                     'offset_column',
#                                                     'fold_column'],
#                      'label': 'ignored_columns',
#                      'level': 'critical',
#                      'name': 'ignored_columns',
#                      'required': False,
#                      'type': 'string[]',
#                      'values': []},
#  'initial_biases': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                                'schema_type': 'Iced',
#                                'schema_version': 3},
#                     'actual_value': None,
#                     'default_value': None,
#                     'gridable': True,
#                     'help': 'A list of H2OFrame ids to initialize the bias '
#                             'vectors of this model with.',
#                     'is_member_of_frames': [],
#                     'is_mutually_exclusive_with': [],
#                     'label': 'initial_biases',
#                     'level': 'expert',
#                     'name': 'initial_biases',
#                     'required': False,
#                     'type': 'Key<Frame>[]',
#                     'values': []},
#  'initial_weight_distribution': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                                             'schema_type': 'Iced',
#                                             'schema_version': 3},
#                                  'actual_value': 'UniformAdaptive',
#                                  'default_value': 'UniformAdaptive',
#                                  'gridable': True,
#                                  'help': 'Initial weight distribution.',
#                                  'is_member_of_frames': [],
#                                  'is_mutually_exclusive_with': [],
#                                  'label': 'initial_weight_distribution',
#                                  'level': 'expert',
#                                  'name': 'initial_weight_distribution',
#                                  'required': False,
#                                  'type': 'enum',
#                                  'values': ['UniformAdaptive',
#                                             'Uniform',
#                                             'Normal']},
#  'initial_weight_scale': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                                      'schema_type': 'Iced',
#                                      'schema_version': 3},
#                           'actual_value': 1.0,
#                           'default_value': 1.0,
#                           'gridable': True,
#                           'help': 'Uniform: -value...value, Normal: stddev.',
#                           'is_member_of_frames': [],
#                           'is_mutually_exclusive_with': [],
#                           'label': 'initial_weight_scale',
#                           'level': 'expert',
#                           'name': 'initial_weight_scale',
#                           'required': False,
#                           'type': 'double',
#                           'values': []},
#  'initial_weights': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                                 'schema_type': 'Iced',
#                                 'schema_version': 3},
#                      'actual_value': None,
#                      'default_value': None,
#                      'gridable': True,
#                      'help': 'A list of H2OFrame ids to initialize the weight '
#                              'matrices of this model with.',
#                      'is_member_of_frames': [],
#                      'is_mutually_exclusive_with': [],
#                      'label': 'initial_weights',
#                      'level': 'expert',
#                      'name': 'initial_weights',
#                      'required': False,
#                      'type': 'Key<Frame>[]',
#                      'values': []},
#  'input_dropout_ratio': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                                     'schema_type': 'Iced',
#                                     'schema_version': 3},
#                          'actual_value': 0.0,
#                          'default_value': 0.0,
#                          'gridable': True,
#                          'help': 'Input layer dropout ratio (can improve '
#                                  'generalization, try 0.1 or 0.2).',
#                          'is_member_of_frames': [],
#                          'is_mutually_exclusive_with': [],
#                          'label': 'input_dropout_ratio',
#                          'level': 'secondary',
#                          'name': 'input_dropout_ratio',
#                          'required': False,
#                          'type': 'double',
#                          'values': []},
#  'keep_cross_validation_fold_assignment': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                                                       'schema_type': 'Iced',
#                                                       'schema_version': 3},
#                                            'actual_value': True,
#                                            'default_value': False,
#                                            'gridable': False,
#                                            'help': 'Whether to keep the '
#                                                    'cross-validation fold '
#                                                    'assignment.',
#                                            'is_member_of_frames': [],
#                                            'is_mutually_exclusive_with': [],
#                                            'label': 'keep_cross_validation_fold_assignment',
#                                            'level': 'expert',
#                                            'name': 'keep_cross_validation_fold_assignment',
#                                            'required': False,
#                                            'type': 'boolean',
#                                            'values': []},
#  'keep_cross_validation_predictions': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                                                   'schema_type': 'Iced',
#                                                   'schema_version': 3},
#                                        'actual_value': True,
#                                        'default_value': False,
#                                        'gridable': False,
#                                        'help': 'Whether to keep the '
#                                                'predictions of the '
#                                                'cross-validation models.',
#                                        'is_member_of_frames': [],
#                                        'is_mutually_exclusive_with': [],
#                                        'label': 'keep_cross_validation_predictions',
#                                        'level': 'expert',
#                                        'name': 'keep_cross_validation_predictions',
#                                        'required': False,
#                                        'type': 'boolean',
#                                        'values': []},
#  'l1': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                    'schema_type': 'Iced',
#                    'schema_version': 3},
#         'actual_value': 0.0,
#         'default_value': 0.0,
#         'gridable': True,
#         'help': 'L1 regularization (can add stability and improve '
#                 'generalization, causes many weights to become 0).',
#         'is_member_of_frames': [],
#         'is_mutually_exclusive_with': [],
#         'label': 'l1',
#         'level': 'secondary',
#         'name': 'l1',
#         'required': False,
#         'type': 'double',
#         'values': []},
#  'l2': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                    'schema_type': 'Iced',
#                    'schema_version': 3},
#         'actual_value': 0.005,
#         'default_value': 0.0,
#         'gridable': True,
#         'help': 'L2 regularization (can add stability and improve '
#                 'generalization, causes many weights to be small.',
#         'is_member_of_frames': [],
#         'is_mutually_exclusive_with': [],
#         'label': 'l2',
#         'level': 'secondary',
#         'name': 'l2',
#         'required': False,
#         'type': 'double',
#         'values': []},
#  'loss': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                      'schema_type': 'Iced',
#                      'schema_version': 3},
#           'actual_value': 'Automatic',
#           'default_value': 'Automatic',
#           'gridable': True,
#           'help': 'Loss function.',
#           'is_member_of_frames': [],
#           'is_mutually_exclusive_with': [],
#           'label': 'loss',
#           'level': 'secondary',
#           'name': 'loss',
#           'required': False,
#           'type': 'enum',
#           'values': ['Automatic',
#                      'CrossEntropy',
#                      'Quadratic',
#                      'Huber',
#                      'Absolute',
#                      'Quantile']},
#  'max_after_balance_size': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                                        'schema_type': 'Iced',
#                                        'schema_version': 3},
#                             'actual_value': 5.0,
#                             'default_value': 5.0,
#                             'gridable': False,
#                             'help': 'Maximum relative size of the training '
#                                     'data after balancing class counts (can be '
#                                     'less than 1.0). Requires balance_classes.',
#                             'is_member_of_frames': [],
#                             'is_mutually_exclusive_with': [],
#                             'label': 'max_after_balance_size',
#                             'level': 'expert',
#                             'name': 'max_after_balance_size',
#                             'required': False,
#                             'type': 'float',
#                             'values': []},
#  'max_categorical_features': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                                          'schema_type': 'Iced',
#                                          'schema_version': 3},
#                               'actual_value': 2147483647,
#                               'default_value': 2147483647,
#                               'gridable': True,
#                               'help': 'Max. number of categorical features, '
#                                       'enforced via hashing. #Experimental',
#                               'is_member_of_frames': [],
#                               'is_mutually_exclusive_with': [],
#                               'label': 'max_categorical_features',
#                               'level': 'expert',
#                               'name': 'max_categorical_features',
#                               'required': False,
#                               'type': 'int',
#                               'values': []},
#  'max_confusion_matrix_size': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                                           'schema_type': 'Iced',
#                                           'schema_version': 3},
#                                'actual_value': 20,
#                                'default_value': 20,
#                                'gridable': False,
#                                'help': '[Deprecated] Maximum size (# classes) '
#                                        'for confusion matrices to be printed '
#                                        'in the Logs.',
#                                'is_member_of_frames': [],
#                                'is_mutually_exclusive_with': [],
#                                'label': 'max_confusion_matrix_size',
#                                'level': 'secondary',
#                                'name': 'max_confusion_matrix_size',
#                                'required': False,
#                                'type': 'int',
#                                'values': []},
#  'max_hit_ratio_k': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                                 'schema_type': 'Iced',
#                                 'schema_version': 3},
#                      'actual_value': 0,
#                      'default_value': 0,
#                      'gridable': True,
#                      'help': 'Max. number (top K) of predictions to use for '
#                              'hit ratio computation (for multi-class only, 0 '
#                              'to disable).',
#                      'is_member_of_frames': [],
#                      'is_mutually_exclusive_with': [],
#                      'label': 'max_hit_ratio_k',
#                      'level': 'secondary',
#                      'name': 'max_hit_ratio_k',
#                      'required': False,
#                      'type': 'int',
#                      'values': []},
#  'max_runtime_secs': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                                  'schema_type': 'Iced',
#                                  'schema_version': 3},
#                       'actual_value': 0.0,
#                       'default_value': 0.0,
#                       'gridable': True,
#                       'help': 'Maximum allowed runtime in seconds for model '
#                               'training. Use 0 to disable.',
#                       'is_member_of_frames': [],
#                       'is_mutually_exclusive_with': [],
#                       'label': 'max_runtime_secs',
#                       'level': 'secondary',
#                       'name': 'max_runtime_secs',
#                       'required': False,
#                       'type': 'double',
#                       'values': []},
#  'max_w2': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                        'schema_type': 'Iced',
#                        'schema_version': 3},
#             'actual_value': 3.4028235e+38,
#             'default_value': 3.4028235e+38,
#             'gridable': True,
#             'help': 'Constraint for squared sum of incoming weights per unit '
#                     '(e.g. for Rectifier).',
#             'is_member_of_frames': [],
#             'is_mutually_exclusive_with': [],
#             'label': 'max_w2',
#             'level': 'expert',
#             'name': 'max_w2',
#             'required': False,
#             'type': 'float',
#             'values': []},
#  'mini_batch_size': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                                 'schema_type': 'Iced',
#                                 'schema_version': 3},
#                      'actual_value': 1,
#                      'default_value': 1,
#                      'gridable': False,
#                      'help': 'Mini-batch size (smaller leads to better fit, '
#                              'larger can speed up and generalize better).',
#                      'is_member_of_frames': [],
#                      'is_mutually_exclusive_with': [],
#                      'label': 'mini_batch_size',
#                      'level': 'expert',
#                      'name': 'mini_batch_size',
#                      'required': False,
#                      'type': 'int',
#                      'values': []},
#  'missing_values_handling': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                                         'schema_type': 'Iced',
#                                         'schema_version': 3},
#                              'actual_value': 'MeanImputation',
#                              'default_value': 'MeanImputation',
#                              'gridable': True,
#                              'help': 'Handling of missing values. Either '
#                                      'MeanImputation or Skip.',
#                              'is_member_of_frames': [],
#                              'is_mutually_exclusive_with': [],
#                              'label': 'missing_values_handling',
#                              'level': 'expert',
#                              'name': 'missing_values_handling',
#                              'required': False,
#                              'type': 'enum',
#                              'values': ['MeanImputation', 'Skip']},
#  'model_id': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                          'schema_type': 'Iced',
#                          'schema_version': 3},
#               'actual_value': {'URL': '/3/Models/H2ODeepLearningEstimator_1496401427.7939088.2',
#                                '__meta': {'schema_name': 'ModelKeyV3',
#                                           'schema_type': 'Key<Model>',
#                                           'schema_version': 3},
#                                'name': 'H2ODeepLearningEstimator_1496401427.7939088.2',
#                                'type': 'Key<Model>'},
#               'default_value': None,
#               'gridable': False,
#               'help': 'Destination id for this model; auto-generated if not '
#                       'specified.',
#               'is_member_of_frames': [],
#               'is_mutually_exclusive_with': [],
#               'label': 'model_id',
#               'level': 'critical',
#               'name': 'model_id',
#               'required': False,
#               'type': 'Key<Model>',
#               'values': []},
#  'momentum_ramp': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                               'schema_type': 'Iced',
#                               'schema_version': 3},
#                    'actual_value': 1000000.0,
#                    'default_value': 1000000.0,
#                    'gridable': True,
#                    'help': 'Number of training samples for which momentum '
#                            'increases.',
#                    'is_member_of_frames': [],
#                    'is_mutually_exclusive_with': [],
#                    'label': 'momentum_ramp',
#                    'level': 'expert',
#                    'name': 'momentum_ramp',
#                    'required': False,
#                    'type': 'double',
#                    'values': []},
#  'momentum_stable': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                                 'schema_type': 'Iced',
#                                 'schema_version': 3},
#                      'actual_value': 0.0,
#                      'default_value': 0.0,
#                      'gridable': True,
#                      'help': 'Final momentum after the ramp is over (try '
#                              '0.99).',
#                      'is_member_of_frames': [],
#                      'is_mutually_exclusive_with': [],
#                      'label': 'momentum_stable',
#                      'level': 'expert',
#                      'name': 'momentum_stable',
#                      'required': False,
#                      'type': 'double',
#                      'values': []},
#  'momentum_start': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                                'schema_type': 'Iced',
#                                'schema_version': 3},
#                     'actual_value': 0.0,
#                     'default_value': 0.0,
#                     'gridable': True,
#                     'help': 'Initial momentum at the beginning of training '
#                             '(try 0.5).',
#                     'is_member_of_frames': [],
#                     'is_mutually_exclusive_with': [],
#                     'label': 'momentum_start',
#                     'level': 'expert',
#                     'name': 'momentum_start',
#                     'required': False,
#                     'type': 'double',
#                     'values': []},
#  'nesterov_accelerated_gradient': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                                               'schema_type': 'Iced',
#                                               'schema_version': 3},
#                                    'actual_value': True,
#                                    'default_value': True,
#                                    'gridable': True,
#                                    'help': 'Use Nesterov accelerated gradient '
#                                            '(recommended).',
#                                    'is_member_of_frames': [],
#                                    'is_mutually_exclusive_with': [],
#                                    'label': 'nesterov_accelerated_gradient',
#                                    'level': 'expert',
#                                    'name': 'nesterov_accelerated_gradient',
#                                    'required': False,
#                                    'type': 'boolean',
#                                    'values': []},
#  'nfolds': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                        'schema_type': 'Iced',
#                        'schema_version': 3},
#             'actual_value': 2,
#             'default_value': 0,
#             'gridable': False,
#             'help': 'Number of folds for N-fold cross-validation (0 to disable '
#                     'or >= 2).',
#             'is_member_of_frames': [],
#             'is_mutually_exclusive_with': [],
#             'label': 'nfolds',
#             'level': 'critical',
#             'name': 'nfolds',
#             'required': False,
#             'type': 'int',
#             'values': []},
#  'offset_column': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                               'schema_type': 'Iced',
#                               'schema_version': 3},
#                    'actual_value': None,
#                    'default_value': None,
#                    'gridable': True,
#                    'help': 'Offset column. This will be added to the '
#                            'combination of columns before applying the link '
#                            'function.',
#                    'is_member_of_frames': ['training_frame',
#                                            'validation_frame'],
#                    'is_mutually_exclusive_with': ['response_column',
#                                                   'weights_column',
#                                                   'ignored_columns',
#                                                   'fold_column'],
#                    'label': 'offset_column',
#                    'level': 'secondary',
#                    'name': 'offset_column',
#                    'required': False,
#                    'type': 'VecSpecifier',
#                    'values': []},
#  'overwrite_with_best_model': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                                           'schema_type': 'Iced',
#                                           'schema_version': 3},
#                                'actual_value': False,
#                                'default_value': True,
#                                'gridable': True,
#                                'help': 'If enabled, override the final model '
#                                        'with the best model found during '
#                                        'training.',
#                                'is_member_of_frames': [],
#                                'is_mutually_exclusive_with': [],
#                                'label': 'overwrite_with_best_model',
#                                'level': 'expert',
#                                'name': 'overwrite_with_best_model',
#                                'required': False,
#                                'type': 'boolean',
#                                'values': []},
#  'pretrained_autoencoder': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                                        'schema_type': 'Iced',
#                                        'schema_version': 3},
#                             'actual_value': None,
#                             'default_value': None,
#                             'gridable': False,
#                             'help': 'Pretrained autoencoder model to '
#                                     'initialize this model with.',
#                             'is_member_of_frames': [],
#                             'is_mutually_exclusive_with': [],
#                             'label': 'pretrained_autoencoder',
#                             'level': 'expert',
#                             'name': 'pretrained_autoencoder',
#                             'required': False,
#                             'type': 'Key<Model>',
#                             'values': []},
#  'quantile_alpha': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                                'schema_type': 'Iced',
#                                'schema_version': 3},
#                     'actual_value': 0.5,
#                     'default_value': 0.5,
#                     'gridable': True,
#                     'help': 'Desired quantile for Quantile regression, must be '
#                             'between 0 and 1.',
#                     'is_member_of_frames': [],
#                     'is_mutually_exclusive_with': [],
#                     'label': 'quantile_alpha',
# ...
#           'level': 'expert',
#           'name': 'seed',
#           'required': False,
#           'type': 'long',
#           'values': []},
#  'shuffle_training_data': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                                       'schema_type': 'Iced',
#                                       'schema_version': 3},
#                            'actual_value': False,
#                            'default_value': False,
#                            'gridable': True,
#                            'help': 'Enable shuffling of training data '
#                                    '(recommended if training data is '
#                                    'replicated and train_samples_per_iteration '
#                                    'is close to #nodes x #rows, of if using '
#                                    'balance_classes).',
#                            'is_member_of_frames': [],
#                            'is_mutually_exclusive_with': [],
#                            'label': 'shuffle_training_data',
#                            'level': 'expert',
#                            'name': 'shuffle_training_data',
#                            'required': False,
#                            'type': 'boolean',
#                            'values': []},
#  'single_node_mode': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                                  'schema_type': 'Iced',
#                                  'schema_version': 3},
#                       'actual_value': False,
#                       'default_value': False,
#                       'gridable': True,
#                       'help': 'Run on a single node for fine-tuning of model '
#                               'parameters.',
#                       'is_member_of_frames': [],
#                       'is_mutually_exclusive_with': [],
#                       'label': 'single_node_mode',
#                       'level': 'expert',
#                       'name': 'single_node_mode',
#                       'required': False,
#                       'type': 'boolean',
#                       'values': []},
#  'sparse': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                        'schema_type': 'Iced',
#                        'schema_version': 3},
#             'actual_value': False,
#             'default_value': False,
#             'gridable': True,
#             'help': 'Sparse data handling (more efficient for data with lots '
#                     'of 0 values).',
#             'is_member_of_frames': [],
#             'is_mutually_exclusive_with': [],
#             'label': 'sparse',
#             'level': 'expert',
#             'name': 'sparse',
#             'required': False,
#             'type': 'boolean',
#             'values': []},
#  'sparsity_beta': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                               'schema_type': 'Iced',
#                               'schema_version': 3},
#                    'actual_value': 0.0,
#                    'default_value': 0.0,
#                    'gridable': True,
#                    'help': 'Sparsity regularization. #Experimental',
#                    'is_member_of_frames': [],
#                    'is_mutually_exclusive_with': [],
#                    'label': 'sparsity_beta',
#                    'level': 'expert',
#                    'name': 'sparsity_beta',
#                    'required': False,
#                    'type': 'double',
#                    'values': []},
#  'standardize': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                             'schema_type': 'Iced',
#                             'schema_version': 3},
#                  'actual_value': False,
#                  'default_value': True,
#                  'gridable': True,
#                  'help': 'If enabled, automatically standardize the data. If '
#                          'disabled, the user must provide properly scaled '
#                          'input data.',
#                  'is_member_of_frames': [],
#                  'is_mutually_exclusive_with': [],
#                  'label': 'standardize',
#                  'level': 'secondary',
#                  'name': 'standardize',
#                  'required': False,
#                  'type': 'boolean',
#                  'values': []},
#  'stopping_metric': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                                 'schema_type': 'Iced',
#                                 'schema_version': 3},
#                      'actual_value': 'AUTO',
#                      'default_value': 'AUTO',
#                      'gridable': True,
#                      'help': 'Metric to use for early stopping (AUTO: logloss '
#                              'for classification, deviance for regression)',
#                      'is_member_of_frames': [],
#                      'is_mutually_exclusive_with': [],
#                      'label': 'stopping_metric',
#                      'level': 'secondary',
#                      'name': 'stopping_metric',
#                      'required': False,
#                      'type': 'enum',
#                      'values': ['AUTO',
#                                 'deviance',
#                                 'logloss',
#                                 'MSE',
#                                 'RMSE',
#                                 'MAE',
#                                 'RMSLE',
#                                 'AUC',
#                                 'lift_top_group',
#                                 'misclassification',
#                                 'mean_per_class_error']},
#  'stopping_rounds': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                                 'schema_type': 'Iced',
#                                 'schema_version': 3},
#                      'actual_value': 0,
#                      'default_value': 5,
#                      'gridable': True,
#                      'help': 'Early stopping based on convergence of '
#                              'stopping_metric. Stop if simple moving average '
#                              'of length k of the stopping_metric does not '
#                              'improve for k:=stopping_rounds scoring events (0 '
#                              'to disable)',
#                      'is_member_of_frames': [],
#                      'is_mutually_exclusive_with': [],
#                      'label': 'stopping_rounds',
#                      'level': 'secondary',
#                      'name': 'stopping_rounds',
#                      'required': False,
#                      'type': 'int',
#                      'values': []},
#  'stopping_tolerance': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                                    'schema_type': 'Iced',
#                                    'schema_version': 3},
#                         'actual_value': 0.0,
#                         'default_value': 0.0,
#                         'gridable': True,
#                         'help': 'Relative tolerance for metric-based stopping '
#                                 'criterion (stop if relative improvement is '
#                                 'not at least this much)',
#                         'is_member_of_frames': [],
#                         'is_mutually_exclusive_with': [],
#                         'label': 'stopping_tolerance',
#                         'level': 'secondary',
#                         'name': 'stopping_tolerance',
#                         'required': False,
#                         'type': 'double',
#                         'values': []},
#  'target_ratio_comm_to_comp': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                                           'schema_type': 'Iced',
#                                           'schema_version': 3},
#                                'actual_value': 0.5,
#                                'default_value': 0.05,
#                                'gridable': True,
#                                'help': 'Target ratio of communication overhead '
#                                        'to computation. Only for multi-node '
#                                        'operation and '
#                                        'train_samples_per_iteration = -2 '
#                                        '(auto-tuning).',
#                                'is_member_of_frames': [],
#                                'is_mutually_exclusive_with': [],
#                                'label': 'target_ratio_comm_to_comp',
#                                'level': 'expert',
#                                'name': 'target_ratio_comm_to_comp',
#                                'required': False,
#                                'type': 'double',
#                                'values': []},
#  'train_samples_per_iteration': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                                             'schema_type': 'Iced',
#                                             'schema_version': 3},
#                                  'actual_value': 128,
#                                  'default_value': -2,
#                                  'gridable': True,
#                                  'help': 'Number of training samples '
#                                          '(globally) per MapReduce iteration. '
#                                          'Special values are 0: one epoch, -1: '
#                                          'all available data (e.g., replicated '
#                                          'training data), -2: automatic.',
#                                  'is_member_of_frames': [],
#                                  'is_mutually_exclusive_with': [],
#                                  'label': 'train_samples_per_iteration',
#                                  'level': 'secondary',
#                                  'name': 'train_samples_per_iteration',
#                                  'required': False,
#                                  'type': 'long',
#                                  'values': []},
#  'training_frame': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                                'schema_type': 'Iced',
#                                'schema_version': 3},
#                     'actual_value': {'URL': '/3/Frames/py_15_sid_b8c2',
#                                      '__meta': {'schema_name': 'FrameKeyV3',
#                                                 'schema_type': 'Key<Frame>',
#                                                 'schema_version': 3},
#                                      'name': 'py_15_sid_b8c2',
#                                      'type': 'Key<Frame>'},
#                     'default_value': None,
#                     'gridable': False,
#                     'help': 'Id of the training data frame (Not required, to '
#                             'allow initial validation of model parameters).',
#                     'is_member_of_frames': [],
#                     'is_mutually_exclusive_with': [],
#                     'label': 'training_frame',
#                     'level': 'critical',
#                     'name': 'training_frame',
#                     'required': False,
#                     'type': 'Key<Frame>',
#                     'values': []},
#  'tweedie_power': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                               'schema_type': 'Iced',
#                               'schema_version': 3},
#                    'actual_value': 1.5,
#                    'default_value': 1.5,
#                    'gridable': True,
#                    'help': 'Tweedie power for Tweedie regression, must be '
#                            'between 1 and 2.',
#                    'is_member_of_frames': [],
#                    'is_mutually_exclusive_with': [],
#                    'label': 'tweedie_power',
#                    'level': 'secondary',
#                    'name': 'tweedie_power',
#                    'required': False,
#                    'type': 'double',
#                    'values': []},
#  'use_all_factor_levels': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                                       'schema_type': 'Iced',
#                                       'schema_version': 3},
#                            'actual_value': True,
#                            'default_value': True,
#                            'gridable': True,
#                            'help': 'Use all factor levels of categorical '
#                                    'variables. Otherwise, the first factor '
#                                    'level is omitted (without loss of '
#                                    'accuracy). Useful for variable importances '
#                                    'and auto-enabled for autoencoder.',
#                            'is_member_of_frames': [],
#                            'is_mutually_exclusive_with': [],
#                            'label': 'use_all_factor_levels',
#                            'level': 'secondary',
#                            'name': 'use_all_factor_levels',
#                            'required': False,
#                            'type': 'boolean',
#                            'values': []},
#  'validation_frame': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                                  'schema_type': 'Iced',
#                                  'schema_version': 3},
#                       'actual_value': None,
#                       'default_value': None,
#                       'gridable': True,
#                       'help': 'Id of the validation data frame.',
#                       'is_member_of_frames': [],
#                       'is_mutually_exclusive_with': [],
#                       'label': 'validation_frame',
#                       'level': 'critical',
#                       'name': 'validation_frame',
#                       'required': False,
#                       'type': 'Key<Frame>',
#                       'values': []},
#  'variable_importances': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                                      'schema_type': 'Iced',
#                                      'schema_version': 3},
#                           'actual_value': False,
#                           'default_value': False,
#                           'gridable': True,
#                           'help': 'Compute variable importances for input '
#                                   'features (Gedeon method) - can be slow for '
#                                   'large networks.',
#                           'is_member_of_frames': [],
#                           'is_mutually_exclusive_with': [],
#                           'label': 'variable_importances',
#                           'level': 'critical',
#                           'name': 'variable_importances',
#                           'required': False,
#                           'type': 'boolean',
#                           'values': []},
#  'weights_column': {'__meta': {'schema_name': 'ModelParameterSchemaV3',
#                                'schema_type': 'Iced',
#                                'schema_version': 3},
#                     'actual_value': None,
#                     'default_value': None,
#                     'gridable': True,
#                     'help': 'Column with observation weights. Giving some '
#                             'observation a weight of zero is equivalent to '
#                             'excluding it from the dataset; giving an '
#                             'observation a relative weight of 2 is equivalent '
#                             'to repeating that row twice. Negative weights are '
#                             'not allowed.',
#                     'is_member_of_frames': ['training_frame',
#                                             'validation_frame'],
#                     'is_mutually_exclusive_with': ['response_column',
#                                                    'ignored_columns',
#                                                    'offset_column',
#                                                    'fold_column'],
#                     'label': 'weights_column',
#                     'level': 'secondary',
#                     'name': 'weights_column',
#                     'required': False,
#                     'type': 'VecSpecifier',
#                     'values': []}}

# %%
print(type(params))
for key, values in params.items():
    #print( 'key: %s - Value %s'% (key, values['actual_value']))
    if values['actual_value'] != values['default_value'] and key not in ['model_id','training_frame','validation_frame','response_column']:
        print( 'ALERT: Modified key: %s - New Value %s - Default Value %s'% (key,values['actual_value'], values['default_value'] ))
    elif key not in ['model_id','training_frame','validation_frame','response_column']:
        print( 'Info: Full Stack Key: %s - New Value %s - Default Value %s'% (key,values['actual_value'], values['default_value'] ))
# Out:
# <class 'dict'>
# Info: Full Stack Key: pretrained_autoencoder - New Value None - Default Value None
# Info: Full Stack Key: regression_stop - New Value 1e-06 - Default Value 1e-06
# Info: Full Stack Key: balance_classes - New Value False - Default Value False
# Info: Full Stack Key: force_load_balance - New Value True - Default Value True
# Info: Full Stack Key: max_after_balance_size - New Value 5.0 - Default Value 5.0
# Info: Full Stack Key: shuffle_training_data - New Value False - Default Value False
# ALERT: Modified key: score_each_iteration - New Value True - Default Value False
# Info: Full Stack Key: average_activation - New Value 0.0 - Default Value 0.0
# Info: Full Stack Key: loss - New Value Automatic - Default Value Automatic
# Info: Full Stack Key: checkpoint - New Value None - Default Value None
# Info: Full Stack Key: rate_decay - New Value 1.0 - Default Value 1.0
# Info: Full Stack Key: initial_weights - New Value None - Default Value None
# Info: Full Stack Key: stopping_metric - New Value AUTO - Default Value AUTO
# Info: Full Stack Key: input_dropout_ratio - New Value 0.0 - Default Value 0.0
# Info: Full Stack Key: score_validation_samples - New Value 0 - Default Value 0
# Info: Full Stack Key: elastic_averaging - New Value False - Default Value False
# Info: Full Stack Key: max_categorical_features - New Value 2147483647 - Default Value 2147483647
# Info: Full Stack Key: quantile_alpha - New Value 0.5 - Default Value 0.5
# ALERT: Modified key: target_ratio_comm_to_comp - New Value 0.5 - Default Value 0.05
# Info: Full Stack Key: momentum_stable - New Value 0.0 - Default Value 0.0
# ALERT: Modified key: l2 - New Value 0.005 - Default Value 0.0
# Info: Full Stack Key: initial_weight_distribution - New Value UniformAdaptive - Default Value UniformAdaptive
# ALERT: Modified key: epochs - New Value 0.11740050084965119 - Default Value 10.0
# Info: Full Stack Key: fold_assignment - New Value AUTO - Default Value AUTO
# ALERT: Modified key: nfolds - New Value 2 - Default Value 0
# Info: Full Stack Key: max_runtime_secs - New Value 0.0 - Default Value 0.0
# Info: Full Stack Key: categorical_encoding - New Value AUTO - Default Value AUTO
# Info: Full Stack Key: score_validation_sampling - New Value Uniform - Default Value Uniform
# Info: Full Stack Key: diagnostics - New Value True - Default Value True
# Info: Full Stack Key: huber_alpha - New Value 0.9 - Default Value 0.9
# Info: Full Stack Key: export_weights_and_biases - New Value False - Default Value False
# ALERT: Modified key: standardize - New Value False - Default Value True
# Info: Full Stack Key: sparse - New Value False - Default Value False
# ALERT: Modified key: keep_cross_validation_predictions - New Value True - Default Value False
# Info: Full Stack Key: weights_column - New Value None - Default Value None
# Info: Full Stack Key: class_sampling_factors - New Value None - Default Value None
# Info: Full Stack Key: initial_biases - New Value None - Default Value None
# Info: Full Stack Key: single_node_mode - New Value False - Default Value False
# Info: Full Stack Key: mini_batch_size - New Value 1 - Default Value 1
# Info: Full Stack Key: activation - New Value Rectifier - Default Value Rectifier
# ALERT: Modified key: rate_annealing - New Value 0.0001 - Default Value 1e-06
# ALERT: Modified key: train_samples_per_iteration - New Value 128 - Default Value -2
# Info: Full Stack Key: col_major - New Value False - Default Value False
# Info: Full Stack Key: stopping_tolerance - New Value 0.0 - Default Value 0.0
# ALERT: Modified key: rate - New Value 0.05 - Default Value 0.005
# Info: Full Stack Key: use_all_factor_levels - New Value True - Default Value True
# Info: Full Stack Key: score_duty_cycle - New Value 0.1 - Default Value 0.1
# Info: Full Stack Key: l1 - New Value 0.0 - Default Value 0.0
# Info: Full Stack Key: ignored_columns - New Value None - Default Value None
# Info: Full Stack Key: max_w2 - New Value 3.4028235e+38 - Default Value 3.4028235e+38
# Info: Full Stack Key: nesterov_accelerated_gradient - New Value True - Default Value True
# Info: Full Stack Key: fast_mode - New Value True - Default Value True
# Info: Full Stack Key: hidden_dropout_ratios - New Value None - Default Value None
# Info: Full Stack Key: elastic_averaging_regularization - New Value 0.001 - Default Value 0.001
# Info: Full Stack Key: tweedie_power - New Value 1.5 - Default Value 1.5
# Info: Full Stack Key: fold_column - New Value None - Default Value None
# Info: Full Stack Key: score_training_samples - New Value 10000 - Default Value 10000
# Info: Full Stack Key: initial_weight_scale - New Value 1.0 - Default Value 1.0
# Info: Full Stack Key: offset_column - New Value None - Default Value None
# ALERT: Modified key: overwrite_with_best_model - New Value False - Default Value True
# Info: Full Stack Key: classification_stop - New Value 0.0 - Default Value 0.0
# ALERT: Modified key: seed - New Value -8064143674566111427 - Default Value -1
# Info: Full Stack Key: reproducible - New Value False - Default Value False
# ALERT: Modified key: keep_cross_validation_fold_assignment - New Value True - Default Value False
# ALERT: Modified key: distribution - New Value bernoulli - Default Value AUTO
# Info: Full Stack Key: momentum_start - New Value 0.0 - Default Value 0.0
# Info: Full Stack Key: elastic_averaging_moving_rate - New Value 0.9 - Default Value 0.9
# Info: Full Stack Key: epsilon - New Value 1e-08 - Default Value 1e-08
# Info: Full Stack Key: variable_importances - New Value False - Default Value False
# ALERT: Modified key: stopping_rounds - New Value 0 - Default Value 5
# Info: Full Stack Key: missing_values_handling - New Value MeanImputation - Default Value MeanImputation
# Info: Full Stack Key: autoencoder - New Value False - Default Value False
# Info: Full Stack Key: max_confusion_matrix_size - New Value 20 - Default Value 20
# Info: Full Stack Key: max_hit_ratio_k - New Value 0 - Default Value 0
# Info: Full Stack Key: replicate_training_data - New Value True - Default Value True
# Info: Full Stack Key: sparsity_beta - New Value 0.0 - Default Value 0.0
# Info: Full Stack Key: score_interval - New Value 5.0 - Default Value 5.0
# Info: Full Stack Key: hidden - New Value [200, 200] - Default Value [200, 200]
# Info: Full Stack Key: ignore_const_cols - New Value True - Default Value True
# Info: Full Stack Key: momentum_ramp - New Value 1000000.0 - Default Value 1000000.0
# Info: Full Stack Key: quiet_mode - New Value False - Default Value False
# Info: Full Stack Key: rho - New Value 0.99 - Default Value 0.99
# Info: Full Stack Key: adaptive_rate - New Value True - Default Value True

# %%
h2o.connect()
model = h2o.load_model(r'D:\Data\models\h2o\PoC-binomial\train\models\H2ORandomForestEstimator_1496397096.371754')
# Out:
# Connecting to H2O server at http://localhost:54321... successful.
# --------------------------  ----------------------------
# H2O cluster uptime:         1 hour 30 mins
# H2O cluster version:        3.10.4.6
# H2O cluster version age:    1 month and 1 day
# H2O cluster name:           H2O_from_python_e2its_e2t404
# H2O cluster total nodes:    1
# H2O cluster free memory:    6.177 Gb
# H2O cluster total cores:    8
# H2O cluster allowed cores:  2
# H2O cluster status:         locked, healthy
# H2O connection url:         http://localhost:54321
# H2O connection proxy:
# H2O internal security:      False
# Python version:             3.5.2 final
# --------------------------  ----------------------------

# %%
h2o.cluster().shutdown()

# %%
h2o.session_id()

# %%
h2o.remove_all()
